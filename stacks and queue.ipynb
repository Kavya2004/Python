# %% [markdown]
# # STACK

# %% [raw]
# It is a linear data structure working on the pattern of Last in First Out

# %%
def push(a,val):
    a.append(val)
    print("Element pushed successfully")
def popitem(a):
    val = a.pop()
    print("Popped item =",val)
def peek(a):
    index = len(a)-1
    print("Peek element = ",a[index])
def display(a):
    for i in range(len(a)-1,-1,-1):
                   print(a[i])
    
a = []
while True:
    choice = int(input("1-->Push\n2-->Pop\n3-->Peek\n4-->Display\n5-->Exit\nEnter your choice: "))
    if choice == 1:
        val = int(input("Enter number to push: "))
        push(a,val)
    elif choice==2:
        if len(a)==0:
            print("Empty stack")
        else:
            popitem(a)
    elif choice == 3:
        if len(a)==0:
            print("Empty stack")
        else:
            peek(a)
    elif choice==4:
        if len(a)==0:
            print("Empty stack")
        else:
            display(a)
    else:
        break
# Out:
# 1-->Push
# 2-->Pop
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 1
# Enter number to push: 1
# Element pushed successfully
# 1-->Push
# 2-->Pop
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 1
# Enter number to push: 2
# Element pushed successfully
# 1-->Push
# 2-->Pop
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 1
# Enter number to push: 3
# Element pushed successfully
# 1-->Push
# 2-->Pop
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 4
# 3
# 2
# 1
# 1-->Push
# 2-->Pop
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 3
# Peek element =  3
# 1-->Push
# 2-->Pop
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 2
# Popped item = 3
# 1-->Push
# 2-->Pop
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 5

# %% [markdown]
# # QUEUE

# %% [markdown]
# It works on the pattern of First in First Out

# %%
def enqueue(a,val): #enqueue=insert
    a.append(val)
    if len(a)==1:
        front=rear=0
    else:
        rear = len(a)-1
def dequeue(a):    #dequeque=delete
    if len(a)==0:
        print("Empty Queue")
    else:
        x=a.pop(0)
        print("Dequeued item=",x)
    if len(a)==0:
        front=rear=None
def peek(a):       #peek displays element at index 0
    if len(a)==0:
        print("Empty Queue")
    else:
        front=0
        print(a[front])
def display(a):      #displays all the elements in the Queue
    if len(a)==0:
        print("Empty Queue")
    else:
        for i in range(len(a)):
            print(a[i])
a=[]
front=rear=None
while True:
    ch = int(input("1-->Enqueue\n2-->Dequeue\n3-->Peek\n4-->Display\n5-->Exit\nEnter your choice: "))
    if ch==1:
        val = int(input("Enter value: "))
        enqueue(a,val)
    if ch==2:
        dequeue(a)
    if ch==3:
        peek(a)
    if ch==4:
        display(a)
    if ch==5:
        break
# Out:
# 1-->Enqueue
# 2-->Dequeue
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 1
# Enter value: 1
# 1-->Enqueue
# 2-->Dequeue
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 1
# Enter value: 2
# 1-->Enqueue
# 2-->Dequeue
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 1
# Enter value: 3
# 1-->Enqueue
# 2-->Dequeue
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 1
# Enter value: 4
# 1-->Enqueue
# 2-->Dequeue
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 1
# Enter value: 5
# 1-->Enqueue
# 2-->Dequeue
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 2
# Dequeued item= 1
# 1-->Enqueue
# 2-->Dequeue
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 3
# 2
# 1-->Enqueue
# 2-->Dequeue
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 4
# 2
# 3
# 4
# 5
# 1-->Enqueue
# 2-->Dequeue
# 3-->Peek
# 4-->Display
# 5-->Exit
# Enter your choice: 5
